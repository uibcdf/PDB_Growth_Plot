# %%
import pandas as pd

# %%
data = pd.read_csv("Data_Export_Growth_June_2019.csv")

# %%
data
# Out:
#     Year  Total Number of Entries Available  \
# 0   2019                             153085
# 1   2018                             147517
# 2   2017                             136311
# 3   2016                             125228
# 4   2015                             114402
# 5   2014                             105135
# 6   2013                              95562
# 7   2012                              86213
# 8   2011                              77451
# 9   2010                              69517
# 10  2009                              61768
# 11  2008                              54477
# 12  2007                              47571
# 13  2006                              40436
# 14  2005                              34027
# 15  2004                              28693
# 16  2003                              23544
# 17  2002                              19397
# 18  2001                              16403
# 19  2000                              13589
# ...
